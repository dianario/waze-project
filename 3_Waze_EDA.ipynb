# %% [markdown]
# # **Waze Project**
# **Course 3 - Go Beyond the Numbers: Translate Data into Insights**

# %% [markdown]
# Your team is still in the early stages of their user churn project. So far, you’ve completed a project proposal and used Python to inspect and organize Waze’s user data.
#
# You check your inbox and notice a new message from Chidi Ga, your team’s Senior Data Analyst. Chidi is pleased with the work you have already completed and requests your assistance with exploratory data analysis (EDA) and further data visualization. Harriet Hadzic, Waze's Director of Data Analysis, will want to review a Python notebook that shows your data exploration and visualization.
#
# A notebook was structured and prepared to help you in this project. Please complete the following questions and prepare an executive summary.

# %% [markdown]
# # **Course 3 End-of-course project: Exploratory data analysis**
#
# In this activity, you will examine data provided and prepare it for analysis.
# <br/>
#
# **The purpose** of this project is to conduct exploratory data analysis (EDA) on a provided dataset.
#
# **The goal** is to continue the examination of the data that you began in the previous Course, adding relevant visualizations that help communicate the story that the data tells.
# <br/>
#
#
# *This activity has 4 parts:*
#
# **Part 1:** Imports, links, and loading
#
# **Part 2:** Data Exploration
# *   Data cleaning
#
#
# **Part 3:** Building visualizations
#
# **Part 4:** Evaluating and sharing results
#
# <br/>
#
#
# Follow the instructions and answer the question below to complete the activity. Then, you will complete an executive summary using the questions listed on the [PACE Strategy Document ](https://docs.google.com/document/d/1iSHdbfQR6w8RClJNWai8oJXn9tQmYoTKn6QohuaK4-s/template/preview?resourcekey=0-ZIHnbxL1dd2u9A47iEVXvg).
#
# Be sure to complete this activity before moving on. The next course item will provide you with a completed exemplar to compare to your own work.

# %% [markdown]
# # **Visualize a story in Python**

# %% [markdown]
# # **PACE stages**

# %% [markdown]
# Throughout these project notebooks, you'll see references to the problem-solving framework PACE. The following notebook components are labeled with the respective PACE stage: Plan, Analyze, Construct, and Execute.

# %% [markdown]
# ## **PACE: Plan**
#
# Consider the questions in your PACE Strategy Document to reflect on the Plan stage.

# %% [markdown]
# ### **Task 1. Imports and data loading**
#
# For EDA of the data, import the data and packages that will be most helpful, such as pandas, numpy, and matplotlib.

# %%
# Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset into a dataframe
df = pd.read_csv('waze_dataset.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       14999 non-null  int64
#  1   label                    14299 non-null  object
#  2   sessions                 14999 non-null  int64
#  3   drives                   14999 non-null  int64
#  4   total_sessions           14999 non-null  float64
#  5   n_days_after_onboarding  14999 non-null  int64
#  6   total_navigations_fav1   14999 non-null  int64
#  7   total_navigations_fav2   14999 non-null  int64
#  8   driven_km_drives         14999 non-null  float64
#  9   duration_minutes_drives  14999 non-null  float64
#  10  activity_days            14999 non-null  int64
#  11  driving_days             14999 non-null  int64
#  12  device                   14999 non-null  object
# dtypes: float64(3), int64(8), object(2)
# memory usage: 1.5+ MB

# %% [markdown]
# ## **PACE: Analyze**
#
# Consider the questions in your PACE Strategy Document and those below where applicable to complete your code:
# 1. Does the data need to be restructured or converted into usable formats?
#
# 2. Are there any variables that have missing data?

# %% [markdown]
# **Answers:**
# 1. The data is already well structured, each row corresponds to an individual user, and most variables are the right data type. The `ID` column needs to be converted into a string format. `total_sessions` may require conversion into int.
#
# 2. The `label` variable contains some missing data, based on the .info() output - 700 rows have missing data.

# %% [markdown]
# ### **Task 2. Data exploration and cleaning**
#
# Consider the following questions:
#
#
#
# 1.  Given the scenario, which data columns are most applicable?
#
# 2.  Which data columns can you eliminate, knowing they won’t solve your problem scenario?
#
#
# 3.  How would you check for missing data? And how would you handle missing data (if any)?
#
# 4.  How would you check for outliers? And how would handle outliers (if any)?
#    .

# %% [markdown]
# **Answers:**
# 1.  Based on the scenario, all the variables will be of use, except for `ID`. All of these variables describe the behaviours of Waze users, and could help understand why some users churn.
#
# 2. The ID column is not required. The only useful indormation we get from this column is the knowledge that each row corresponds to a distinct user. Our analysis requires user aggregation based on usage behaviours, so knowledge of indiviual `ID` is not required.
#
# 3. Steps to finding missing data:
#     * Initial Inspection: Use df.info() to get a summary of the DataFrame, including the number of non-null entries for each column.
#     * Count Missing Values: Apply df.isna().sum(). This command returns the count of missing (NaN) values in each column, providing a clearer picture of how widespread the missing values are across the dataset.
#     * Identify Rows with Missing Data: To find specific rows that contain missing values, use the mask df[df.isna().any(axis=1)]. This command filters the DataFrame to only those rows with at least one missing value.
#     * Handling Missing Data: It is important to first establish if the data us missing at random or if there is a bias in which data are missing.The approach to handling missing data will be informed by its context and impact on the analysis. Options include dropping missing data, imputing missing values or using a model to predict missing values.
#
# 4. For handling outliers: Checking the range and distribution of data through summary stats, histograms and box plots will help to identify if there are any global or contextual outliers. Outlier data can either be excluded from analysis or imputed a value, e.g. impute a % value of distribution for values beyond certain thresholds, like is done below. Alternatively, the data could be kept as is.

# %% [markdown]
# #### **Data overview and summary statistics**

# %%
df.head()
# Out:
#    ID     label  sessions  drives  total_sessions  n_days_after_onboarding  \
# 0   0  retained       283     226      296.748273                     2276
# 1   1  retained       133     107      326.896596                     1225
# 2   2  retained       114      95      135.522926                     2651
# 3   3  retained        49      40       67.589221                       15
# 4   4  retained        84      68      168.247020                     1562
#
#    total_navigations_fav1  total_navigations_fav2  driven_km_drives  \
# 0                     208                       0       2628.845068
# 1                      19                      64      13715.920550
# 2                       0                       0       3059.148818
# 3                     322                       7        913.591123
# 4                     166                       5       3950.202008
#
#    duration_minutes_drives  activity_days  driving_days   device
# ...

# %%
df.size
# Out:
# 194987

# %%
df.describe()
# Out:
#                  ID      sessions        drives  total_sessions  \
# count  14999.000000  14999.000000  14999.000000    14999.000000
# mean    7499.000000     80.633776     67.281152      189.964447
# std     4329.982679     80.699065     65.913872      136.405128
# min        0.000000      0.000000      0.000000        0.220211
# 25%     3749.500000     23.000000     20.000000       90.661156
# 50%     7499.000000     56.000000     48.000000      159.568115
# 75%    11248.500000    112.000000     93.000000      254.192341
# max    14998.000000    743.000000    596.000000     1216.154633
#
#        n_days_after_onboarding  total_navigations_fav1  \
# count             14999.000000            14999.000000
# mean               1749.837789              121.605974
# std                1008.513876              148.121544
# min                   4.000000                0.000000
# 25%                 878.000000                9.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       14999 non-null  int64
#  1   label                    14299 non-null  object
#  2   sessions                 14999 non-null  int64
#  3   drives                   14999 non-null  int64
#  4   total_sessions           14999 non-null  float64
#  5   n_days_after_onboarding  14999 non-null  int64
#  6   total_navigations_fav1   14999 non-null  int64
#  7   total_navigations_fav2   14999 non-null  int64
#  8   driven_km_drives         14999 non-null  float64
#  9   duration_minutes_drives  14999 non-null  float64
#  10  activity_days            14999 non-null  int64
#  11  driving_days             14999 non-null  int64
#  12  device                   14999 non-null  object
# dtypes: float64(3), int64(8), object(2)
# memory usage: 1.5+ MB

# %% [markdown]
# ## **PACE: Construct**
#
# Consider the questions in your PACE Strategy Document to reflect on the Construct stage.

# %% [markdown]
# Consider the following questions as you prepare to deal with outliers:
#
# 1.   What are some ways to identify outliers?
# 2.   How do you make the decision to keep or exclude outliers from any future models?

# %% [markdown]
# **Answers**:
# 1. See above answer to question 4.
#
# 2. There are three primary strategies for dealing with outlier values: retention, removal, or modification. The choice among these approaches depends on the specific characteristics of the dataset, confidence in the data, and the objectives of any intended model. Outliers can be removed if there's confidence they result from errors or anomalies in the data and the dataset is destined for modeling or machine learning applications. This option is typically the least favored due to the potential loss of valuable data. Alternatively, outliers can be modified by recalculating their values, eg  if the dataset is small or particularly crucial for modeling or machine learning. This allowsfor a  more accurate analysis without the extreme variation that can result from the outlier data points. Finally, outliers can also be retained, expecially if the model in question can accomodate outliers without siginificant performance degradation or the data is solely used for EDA.

# %% [markdown]
# ### **Task 3a. Visualizations**
#
# Select data visualization types that will help you understand and explain the data.
#
# Now that you know which data columns you’ll use, it is time to decide which data visualization makes the most sense for EDA of the Waze dataset.
#
# **Question:** What type of data visualization(s) will be most helpful?
#
# * Line graph
# * Bar chart
# * Box plot
# * Histogram
# * Heat map
# * Scatter plot
# * A geographic map

# %% [markdown]
# **Response:** A box plot, histograms and scatter plot will serve best to address stakeholder's questions.

# %% [markdown]
# Begin by examining the spread and distribution of important variables using box plots and histograms.

# %% [markdown]
# #### **`sessions`**
#
# _The number of occurrence of a user opening the app during the month_

# %%
# Box plot
plt.figure(figsize=(5,1))
sns.boxplot(data =df,
            x= 'sessions',
            fliersize= 2,
            color='#4285F4'
            )
plt.title('Sessions boxplot')
# Out:
# Text(0.5, 1.0, 'Sessions boxplot')

# %%
# Histogram
plt.figure(figsize=(5, 3))
sesh_hist = sns.histplot(df['sessions'], 
                         binwidth= 5, 
                         color='#4285F4', alpha=1)
median = df.sessions.median()
plt.axvline(median, color = 'black', linestyle = '--')
plt.text(80, 650, f'median = {median}', color = 'black')
plt.xlabel('Sessions')
plt.ylabel('Count')
plt.title('Sessions histogram')
# Out:
# Text(0.5, 1.0, 'Sessions histogram')

# %% [markdown]
# The `sessions` variable is a right-skewed distribution with half of the observations having 56 or fewer sessions. However, as indicated by the boxplot, some users have more than 700.

# %% [markdown]
# #### **`drives`**
#
# _An occurrence of driving at least 1 km during the month_

# %%
# Box plot
plt.figure(figsize=(5,1))
sns.boxplot(data=df,
            x= 'drives',
            fliersize= 2,
            color='#4285F4'
            )
plt.title('Drives boxplot')
# Out:
# Text(0.5, 1.0, 'Drives boxplot')

# %%
# Histogram
plt.figure(figsize=(5, 3))
sesh_hist = sns.histplot(df['drives'], 
                         binwidth= 5, 
                         color='#4285F4', alpha=1)
median = df.drives.median()
plt.axvline(median, color = 'black', linestyle = '--')
plt.text(80, 650, f'median = {median}', color = 'black')
plt.xlabel('Drives')
plt.ylabel('Count')
plt.title('Drives histogram')
# Out:
# Text(0.5, 1.0, 'Drives histogram')

# %% [markdown]
# The `drives` information follows a distribution similar to the `sessions` variable. It is right-skewed, approximately log-normal, with a median of 48. However, some drivers had over 400 drives in the last month.

# %% [markdown]
# #### **`total_sessions`**
#
# _A model estimate of the total number of sessions since a user has onboarded_

# %%
# Box plot
plt.figure(figsize=(5,1))
sns.boxplot(data=df,
            x= 'total_sessions',
            fliersize= 2,
            color='#4285F4'
            )
plt.title('Estimated total sessions boxplot')
# Out:
# Text(0.5, 1.0, 'Estimated total sessions boxplot')

# %%
# Histogram
df['total_sessions'] = df['total_sessions'].astype('int64')
plt.figure(figsize=(5, 3))
sesh_hist = sns.histplot(df['total_sessions'], 
                         binwidth= 5, 
                         color='#4285F4', alpha=1)
median = df.total_sessions.median()
plt.axvline(median, color = 'black', linestyle = '--')
plt.text(210, 250, f'median = {median:.2f}', color = 'black')
plt.xlabel('Total sessions')
plt.ylabel('Count')
plt.title('Estimated total sessions histogram')
# Out:
# Text(0.5, 1.0, 'Estimated total sessions histogram')

# %% [markdown]
# The `total_sessions` is a right-skewed distribution. The median total number of sessions is 159.6. This is interesting information because, if the median number of sessions in the last month was 48 and the median total sessions was ~160, then it seems that a large proportion of a user's total drives might have taken place in the last month. This is something you can examine more closely later.

# %% [markdown]
# #### **`n_days_after_onboarding`**
#
# _The number of days since a user signed up for the app_

# %%
# Box plot
plt.figure(figsize=(5,1))
sns.boxplot(data=df,
            x= 'n_days_after_onboarding',
            fliersize= 2,
            color='#4285F4'
            )
plt.title('Number of days after onboarding boxplot')
# Out:
# Text(0.5, 1.0, 'Number of days after onboarding boxplot')

# %%
# Histogram
plt.figure(figsize=(5, 3))
sesh_hist = sns.histplot(df['n_days_after_onboarding'], 
                         binwidth= 5, 
                         color='#4285F4', alpha=1)
median = df.n_days_after_onboarding.median()
plt.axvline(median, color = 'black', linestyle = '--')
plt.text(0, 35, f'median = {median}', color = 'black')
plt.xlabel('Days after onboarding')
plt.ylabel('Count')
plt.title('Number of days aftrer onboarding histogram')
# Out:
# Text(0.5, 1.0, 'Number of days aftrer onboarding histogram')

# %% [markdown]
# The total user tenure (i.e., number of days since
# onboarding) is a uniform distribution with values ranging from near-zero to \~3,500 (\~9.5 years).

# %% [markdown]
# #### **`driven_km_drives`**
#
# _Total kilometers driven during the month_

# %%
# Box plot
plt.figure(figsize=(5,1))
sns.boxplot(data=df,
            x= 'driven_km_drives',
            fliersize= 2,
            color='#4285F4'
            )
plt.title('Total km driven boxplot')
# Out:
# Text(0.5, 1.0, 'Total km driven boxplot')

# %%
# Histogram
plt.figure(figsize=(5, 3))
sesh_hist = sns.histplot(df['driven_km_drives'], 
                         binwidth= 5, 
                         color='#4285F4', alpha=1)
median = df.driven_km_drives.median()
plt.axvline(median, color = 'black', linestyle = '--')
plt.text(4800, 20, f'median = {median:.2f}', color = 'black')
plt.xlabel('Total km driven')
plt.ylabel('Count')
plt.title('Total km driven histogram')
# Out:
# Text(0.5, 1.0, 'Total km driven histogram')

# %% [markdown]
# The number of drives driven in the last month per user is a right-skewed distribution with half the users driving under 3,495 kilometers. As you discovered in the analysis from the previous course, the users in this dataset drive _a lot_. The longest distance driven in the month was over half the circumferene of the earth.

# %% [markdown]
# #### **`duration_minutes_drives`**
#
# _Total duration driven in minutes during the month_

# %%
# Box plot
plt.figure(figsize=(5,1))
sns.boxplot(data=df,
            x= 'duration_minutes_drives',
            fliersize= 2,
            color='#4285F4'
            )
plt.title('Total minutes driven boxplot')
# Out:
# Text(0.5, 1.0, 'Total minutes driven boxplot')

# %%
# Histogram
plt.figure(figsize=(5, 3))
sesh_hist = sns.histplot(df['duration_minutes_drives'], 
                         binwidth= 5, 
                         color='#4285F4', alpha=1)
median = df.duration_minutes_drives.median()
plt.axvline(median, color = 'black', linestyle = '--')
plt.text(2000, 30, f'median = {median:.2f}', color = 'black')
plt.xlabel('Duration minutes drives')
plt.ylabel('Count')
plt.title('Total minutes driven histogram')
# Out:
# Text(0.5, 1.0, 'Total minutes driven histogram')

# %% [markdown]
# The `duration_minutes_drives` variable has a heavily skewed right tail. Half of the users drove less than \~1,478 minutes (\~25 hours), but some users clocked over 250 hours over the month.

# %% [markdown]
# #### **`activity_days`**
#
# _Number of days the user opens the app during the month_

# %%
# Box plot
plt.figure(figsize=(5,1))
sns.boxplot(data=df,
            x= 'activity_days',
            fliersize= 2,
            color='#4285F4'
            )
plt.title('Activity days boxplot')
# Out:
# Text(0.5, 1.0, 'Activity days boxplot')

# %%
# Histogram
plt.figure(figsize=(5, 3))
sesh_hist = sns.histplot(df['activity_days'], 
                         binwidth= 1, 
                         color='#4285F4', alpha=1)
median = df.activity_days.median()
plt.axvline(median, color = 'black', linestyle = '--')
plt.text(17,600, f'median = {median:.2f}', color = 'black')
plt.xlabel('Activity days')
plt.ylabel('Count')
plt.title('Activity days histogram')
# Out:
# Text(0.5, 1.0, 'Activity days histogram')

# %% [markdown]
# Within the last month, users opened the app a median of 16 times. The box plot reveals a centered distribution. The histogram shows a nearly uniform distribution of ~500 people opening the app on each count of days. However, there are ~250 people who didn't open the app at all and ~250 people who opened the app every day of the month.
#
# This distribution is noteworthy because it does not mirror the `sessions` distribution, which you might think would be closely correlated with `activity_days`.

# %% [markdown]
# #### **`driving_days`**
#
# _Number of days the user drives (at least 1 km) during the month_

# %%
# Box plot
plt.figure(figsize=(5,1))
sns.boxplot(data=df,
            x= 'driving_days',
            fliersize= 2,
            color='#4285F4'
            )
plt.title('Driving days boxplot')
# Out:
# Text(0.5, 1.0, 'Driving days boxplot')

# %%
# Histogram
plt.figure(figsize=(5, 3))
sesh_hist = sns.histplot(df['driving_days'], 
                         binwidth= 1, 
                         color='#4285F4', alpha=1)
median = df.driving_days.median()
plt.axvline(median, color = 'black', linestyle = '--')
plt.text(13,700, f'median = {median:.2f}', color = 'black')
plt.xlabel('Driving days')
plt.ylabel('Count')
plt.title('Driving days histogram')
# Out:
# Text(0.5, 1.0, 'Driving days histogram')

# %% [markdown]
# The number of days users drove each month is almost uniform, and it largely correlates with the number of days they opened the app that month, except the `driving_days` distribution tails off on the right.
#
# However, there were ~1,000 users who did not drive at all during the month. This might seem counterintuitive when considered together with the information from `activity_days`. That variable had \~500 users opening the app on each of most of the day counts, but there were only \~250 users who did not open the app at all during the month and ~250 users who opened the app every day. Flag this for further investigation later.

# %% [markdown]
# #### **`device`**
#
# _The type of device a user starts a session with_

# %%
# Pie chart
device_counts = df['device'].value_counts()

plt.figure(figsize= (3,3))
plt.pie(device_counts, 
        labels = device_counts.index,
        autopct='%1.1f%%',
        startangle= 90,
        )
plt.title('Type of device - pie chart')
# Out:
# Text(0.5, 1.0, 'Type of device - pie chart')

# %% [markdown]
# There are nearly twice as many iPhone users as Android users represented in this data.

# %% [markdown]
# #### **`label`**
#
# _Binary target variable (“retained” vs “churned”) for if a user has churned anytime during the course of the month_

# %%
# Pie chart
label_counts = df['label'].value_counts()

plt.figure(figsize= (3,3))
plt.pie(label_counts, 
        labels = label_counts.index,
        autopct='%1.1f%%',
        startangle= 90,
        )
plt.title('Retained vs churned users - pie chart')
# Out:
# Text(0.5, 1.0, 'Retained vs churned users - pie chart')

# %% [markdown]
# Less than 18% of the users churned.

# %% [markdown]
# #### **`driving_days` vs. `activity_days`**
#
# Because both `driving_days` and `activity_days` represent counts of days over a month and they're also closely related, you can plot them together on a single histogram. This will help to better understand how they relate to each other without having to scroll back and forth comparing histograms in two different places.
#
# Plot a histogram that, for each day, has a bar representing the counts of `driving_days` and `activity_days`.

# %%
# Histogram
plt.figure(figsize=(8, 3))
label = ['driving days', 'activity days']
plt.hist([df['driving_days'], df['activity_days']],
         bins = range(0,33, 1),
         label = label
         )
plt.xlabel('days')
plt.ylabel('Count')
plt.legend()
plt.title('Driving days vs activity days histogram')
plt.show()

# %% [markdown]
# As observed previously, this might seem counterintuitive. After all, why are there _fewer_ people who didn't use the app at all during the month and _more_ people who didn't drive at all during the month?
#
# On the other hand, it could just be illustrative of the fact that, while these variables are related to each other, they're not the same. People probably just open the app more than they use the app to drive&mdash;perhaps to check drive times or route information, to update settings, or even just by mistake.
#
# Nonetheless, it might be worthwile to contact the data team at Waze to get more information about this, especially because it seems that the number of days in the month is not the same between variables.
#
# Confirm the maximum number of days for each variable&mdash;`driving_days` and `activity_days`.

# %%
print(f'Max driving days: {df.driving_days.max()}')
print(f'Max acvtivity days: {df.activity_days.max()}')
# Out:
# Max driving days: 30
# Max acvtivity days: 31

# %% [markdown]
# It's true. Although it's possible that not a single user drove all 31 days of the month, it's highly unlikely, considering there are 15,000 people represented in the dataset.
#
# One other way to check the validity of these variables is to plot a simple scatter plot with the x-axis representing one variable and the y-axis representing the other.

# %%
# Scatter plot
plt.figure(figsize=(5,3))
sns.scatterplot( x= df['driving_days'],
            y = df['activity_days'],
            s=10,
            color = '#4285F4',
            alpha= 0.25)
plt.plot([0,31], [0,31], color='red', linestyle='--');
plt.title('Activity days vs. driving days')
plt.xlabel('Driving days')
plt.ylabel('Activity days')
plt.show()

# %% [markdown]
# Notice that there is a theoretical limit. If you use the app to drive, then by definition it must count as a day-use as well. In other words, you cannot have more drive-days than activity-days. None of the samples in this data violate this rule, which is good.

# %% [markdown]
# #### **Retention by device**
#
# Plot a histogram that has four bars&mdash;one for each device-label combination&mdash;to show how many iPhone users were retained/churned and how many Android users were retained/churned.

# %%
# Histogram
plt.figure(figsize=(5,4))
sns.histplot(data=df,
             x='device',
             hue='label',
             multiple='dodge',
             )

plt.xlabel('Device')
plt.title('Retention by device histogram')
# Out:
# Text(0.5, 1.0, 'Retention by device histogram')

# %% [markdown]
# The proportion of churned users to retained users is consistent between device types.

# %% [markdown]
# #### **Retention by kilometers driven per driving day**
#
# In the previous course, you discovered that the median distance driven last month for users who churned was 8.33 km, versus 3.36 km for people who did not churn. Examine this further.
#
# 1. Create a new column in `df` called `km_per_driving_day`, which represents the mean distance driven per driving day for each user.
#
# 2. Call the `describe()` method on the new column.

# %%
# 1. Create `km_per_driving_day` column
df['km_per_driving_day'] = df['driven_km_drives']/df['driving_days']

# 2. Call `describe()` on the new column
df['km_per_driving_day'].describe()
# Out:
# /home/driossz/miniconda3/envs/data_analytics_env/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# count    1.499900e+04
# mean              inf
# std               NaN
# min      3.022063e+00
# 25%      1.672804e+02
# 50%      3.231459e+02
# 75%      7.579257e+02
# max               inf
# Name: km_per_driving_day, dtype: float64

# %% [markdown]
# What do you notice? The mean value is infinity, the standard deviation is NaN, and the max value is infinity. Why do you think this is?
#
# This is the result of there being values of zero in the `driving_days` column. Pandas imputes a value of infinity in the corresponding rows of the new column because division by zero is undefined.
#
# 1. Convert these values from infinity to zero. You can use `np.inf` to refer to a value of infinity.
#
# 2. Call `describe()` on the `km_per_driving_day` column to verify that it worked.

# %%
# 1. Convert infinite values to zero. Inplace=True avoids the need to asign the data frame to a new variable
df['km_per_driving_day'].replace(np.inf, 0, inplace=True)

# 2. Confirm that it worked
df['km_per_driving_day'].describe()
# Out:
# /tmp/ipykernel_2601/3187853131.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['km_per_driving_day'].replace(np.inf, 0, inplace=True)
# count    14999.000000
# mean       578.963113
# std       1030.094384
# min          0.000000
# 25%        136.238895
# 50%        272.889272
# 75%        558.686918
# max      15420.234110
# Name: km_per_driving_day, dtype: float64

# %% [markdown]
# The maximum value is 15,420 kilometers _per drive day_. This is physically impossible. Driving 100 km/hour for 12 hours is 1,200 km. It's unlikely many people averaged more than this each day they drove, so, for now, disregard rows where the distance in this column is greater than 1,200 km.
#
# Plot a histogram of the new `km_per_driving_day` column, disregarding those users with values greater than 1,200 km. Each bar should be the same length and have two colors, one color representing the percent of the users in that bar that churned and the other representing the percent that were retained. This can be done by setting the `multiple` parameter of seaborn's [`histplot()`](https://seaborn.pydata.org/generated/seaborn.histplot.html) function to `fill`.

# %%
# Histogram
plt.figure(figsize=(8,4))
sns.histplot(data=df[df['km_per_driving_day'] <=1201],
             x='km_per_driving_day',
            bins=range(0,1201,25),
             hue='label',
             multiple='fill',
             )

plt.xlabel('Average km per driving day')
plt.ylabel('Fraction')
plt.title('Churn rate by average km per driving day')
# Out:
# Text(0.5, 1.0, 'Churn rate by average km per driving day')

# %% [markdown]
# The churn rate tends to increase as the mean daily distance driven increases, confirming what was found in the previous course. It would be worth investigating further the reasons for long-distance users to discontinue using the app.

# %% [markdown]
# #### **Churn rate per number of driving days**
#
# Create another histogram just like the previous one, only this time it should represent the churn rate for each number of driving days.

# %%
# Histogram
# Histogram
plt.figure(figsize=(8,4))
sns.histplot(data=df,
             x='driving_days',
            bins=range(0,32,1),
             hue='label',
             multiple='fill',
             )

plt.xlabel('Total driving days')
plt.ylabel('Fraction')
plt.title('Churn rate by driving days')
# Out:
# Text(0.5, 1.0, 'Churn rate by driving days')

# %% [markdown]
# The churn rate is highest for people who didn't use Waze much during the last month. The more times they used the app, the less likely they were to churn. While 40% of the users who didn't use the app at all last month churned, nobody who used the app 30 days churned.
#
# This isn't surprising. If people who used the app a lot churned, it would likely indicate dissatisfaction. When people who don't use the app churn, it might be the result of dissatisfaction in the past, or it might be indicative of a lesser need for a navigational app. Maybe they moved to a city with good public transportation and don't need to drive anymore.

# %% [markdown]
# #### **Proportion of sessions that occurred in the last month**
#
# Create a new column `percent_sessions_in_last_month` that represents the percentage of each user's total sessions that were logged in their last month of use.

# %%
df['percent_sessions_in_last_month'] = df['sessions']/df['total_sessions']
df.head()
# Out:
#    ID     label  sessions  drives  total_sessions  n_days_after_onboarding  \
# 0   0  retained       283     226             296                     2276
# 1   1  retained       133     107             326                     1225
# 2   2  retained       114      95             135                     2651
# 3   3  retained        49      40              67                       15
# 4   4  retained        84      68             168                     1562
#
#    total_navigations_fav1  total_navigations_fav2  driven_km_drives  \
# 0                     208                       0       2628.845068
# 1                      19                      64      13715.920550
# 2                       0                       0       3059.148818
# 3                     322                       7        913.591123
# 4                     166                       5       3950.202008
#
#    duration_minutes_drives  activity_days  driving_days   device  \
# ...

# %% [markdown]
# What is the median value of the new column?

# %%
prct_median = df['percent_sessions_in_last_month'].median()
prct_median
# Out:
# 0.42592592592592593

# %% [markdown]
# Now, create a histogram depicting the distribution of values in this new column.

# %%
# Histogram
plt.figure(figsize = (8,3))
sns.histplot(data = df, 
             x='percent_sessions_in_last_month',
             hue= 'label',
             multiple= 'stack',
             )
plt.axvline(prct_median, color = 'black', linestyle = '--')
plt.text(0.45,700, f'median = {prct_median:.2f}', color = 'black')
plt.title('Percent sessions in last month - histogram')
plt.show()

# %% [markdown]
# Check the median value of the `n_days_after_onboarding` variable.

# %%
df['n_days_after_onboarding'].median()
# Out:
# 1741.0

# %% [markdown]
# Half of the people in the dataset had 40% or more of their sessions in just the last month, yet the overall median time since onboarding is almost five years.
#
# Make a histogram of `n_days_after_onboarding` for just the people who had 40% or more of their total sessions in the last month.

# %%
# Histogram
plt.figure(figsize = (8,3))
sns.histplot(data = df[df['percent_sessions_in_last_month']>=0.4], 
             x='n_days_after_onboarding',
             )

plt.title('Number of days post onboarding for users with >=40% sessions in last month')
plt.show()

# %% [markdown]
# The number of days since onboarding for users with 40% or more of their total sessions occurring in just the last month is a uniform distribution. This is very strange. It's worth asking Waze why so many long-time users suddenly used the app so much in the last month.

# %% [markdown]
# ### **Task 3b. Handling outliers**
#
# The box plots from the previous section indicated that many of these variables have outliers. These outliers do not seem to be data entry errors; they are present because of the right-skewed distributions.
#
# Depending on what you'll be doing with this data, it may be useful to impute outlying data with more reasonable values. One way of performing this imputation is to set a threshold based on a percentile of the distribution.
#
# To practice this technique, write a function that calculates the 95th percentile of a given column, then imputes values > the 95th percentile with the value at the 95th percentile.  such as the 95th percentile of the distribution.

# %%
def impute_percentile_95(df, column_name):
    """ Takes a df column as input, calculates its 95th percentile, then imputes this value to all values above this 95% threshold """
    percent_95_val = np.percentile(df[column_name], 95)
    df.loc[df[column_name]>percent_95_val, column_name] = percent_95_val

# %% [markdown]
# Next, apply that function to the following columns:
# * `sessions`
# * `drives`
# * `total_sessions`
# * `driven_km_drives`
# * `duration_minutes_drives`

# %%
impute_percentile_95(df, 'sessions')
impute_percentile_95(df, 'drives')
impute_percentile_95(df, 'total_sessions')
impute_percentile_95(df, 'driven_km_drives')
impute_percentile_95(df, 'duration_minutes_drives')

# %% [markdown]
# Call `describe()` to see if your change worked.

# %%
df.describe()
# Out:
# /home/driossz/miniconda3/envs/data_analytics_env/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#                  ID      sessions        drives  total_sessions  \
# count  14999.000000  14999.000000  14999.000000    14999.000000
# mean    7499.000000     76.568705     64.058204      183.535969
# std     4329.982679     67.297958     55.306924      118.621443
# min        0.000000      0.000000      0.000000        0.000000
# 25%     3749.500000     23.000000     20.000000       90.000000
# 50%     7499.000000     56.000000     48.000000      159.000000
# 75%    11248.500000    112.000000     93.000000      254.000000
# max    14998.000000    243.000000    201.000000      454.000000
#
#        n_days_after_onboarding  total_navigations_fav1  \
# count             14999.000000            14999.000000
# mean               1749.837789              121.605974
# ...

# %% [markdown]
# #### **Conclusion**
#
# Analysis revealed that the overall churn rate is \~17%, and that this rate is consistent between iPhone users and Android users.
#
# Perhaps you feel that the more deeply you explore the data, the more questions arise. This is not uncommon! In this case, it's worth asking the Waze data team why so many users used the app so much in just the last month.
#
# Also, EDA has revealed that users who drive very long distances on their driving days are _more_ likely to churn, but users who drive more often are _less_ likely to churn. The reason for this discrepancy is an opportunity for further investigation, and it would be something else to ask the Waze data team about.

# %% [markdown]
# ## **PACE: Execute**

# %% [markdown]
# ### **Task 4a. Results and evaluation**
#
# Having built visualizations in Python, what have you learned about the dataset? What other questions have your visualizations uncovered that you should pursue?
#
# **Pro tip:** Put yourself in your client's perspective. What would they want to know?
#
# Use the following code fields to pursue any additional EDA based on the visualizations you've already plotted. Also use the space to make sure your visualizations are clean, easily understandable, and accessible.
#
# **Ask yourself:** Did you consider color, contrast, emphasis, and labeling?

# %% [markdown]
# **I have learned ....**
#
# * The churn `label` contains missing data, so this data will likely require further processing before analysis.
#
# * There were median 56 sessions, 48 drives, median driven distances and time were 3493.86 km and 1478.25 min, respectively. There users had recorced median 159 total sessions, and were median 1741 total days after onboarding.
#
# * Users had median 16 days of activity, while 250 users did not open the app at all. Users had a median 12 driving days. Many more users did not record any drives.
#
# * 35.5% users were on Android, and 64.5% were iPhone users. 18% of the users who were labelled in the dataset churned and 83% were retained. The proportion of churned vs retained users was consistent across the two device types.
#
# * The total number of days in the month is not the same between the variables`driving_days` and `activity_days`. It is not clear why this is the case.
#
# *There are many outlying data points for `km_per_driving_day` and `duration_min_drives` variables, with implausible median values (3500 km and ~24 hrs!). It will be important to investigate what is wrong with the data, e.g. whether it is in wrong units.
#
# **My other questions are ....**
# * Why are there missing values in the `label` column?
# * Who are the users with the extreme number of drives? What is the reason for their extreme driving?
# * Why are there so many extreme values associated with km driven per driving day?
# * Why is it that the more km users drive they are more likely to churn? Why do churned users have more drives than retained users?
# * Is there a difference in days after onboarding between churned and retained users?
# * What are other distinguishing characteristics of churned vs retained users?
#
# **My client would likely want to know ...**
# * What are the key characteristics/variables associated with churned users?
# * Can the company create interventions targeted at any of those characteristics to minimise user churn?

# %% [markdown]
# Use the following two code blocks (add more blocks if you like) to do additional EDA you feel is important based on the given scenario.

# %%
# Assess longevity of app usage 
onboarding = df.groupby('label')['n_days_after_onboarding'].median().reset_index()
onboarding = onboarding.sort_values(by='label', ascending=False)
onboarding

sns.barplot(data=onboarding,
            x= 'label',
            y='n_days_after_onboarding',
            hue='label')
plt.xlabel('User status')
plt.ylabel('Days after user onboarding')
plt.title('Days after onboarding for retained vs churned users')
# Out:
# Text(0.5, 1.0, 'Days after onboarding for retained vs churned users')

# %% [markdown]
# Churned users did not use the app longer than retained users.

# %%
### YOUR CODE HERE ###
df['monthly_drives_per_session_ratio'] = (df['drives']/df['sessions'])
# Histogram
plt.figure(figsize=(8,4))
sns.histplot(data=df,
             x='monthly_drives_per_session_ratio',
             hue='label',
             multiple='fill',
             )

plt.xlabel('Drives per session ratio')
plt.ylabel('Fraction')
plt.title('Churn rate by drives per session')
# Out:
# Text(0.5, 1.0, 'Churn rate by drives per session')

# %% [markdown]
# The ratio of churned vs retained users does not vary with different drives per session ratios

# %% [markdown]
# ### **Task 4b. Conclusion**
#
# Now that you've explored and visualized your data, the next step is to share your findings with Harriet Hadzic, Waze's Director of Data Analysis. Consider the following questions as you prepare to write your executive summary. Think about key points you may want to share with the team, and what information is most relevant to the user churn project.
#
# **Questions:**
#
# 1. What types of distributions did you notice in the variables? What did this tell you about the data?
#
# Almost all the variables displayed significant right-skewness or were evenly spread across their range. In the case of right-skewed distributions, it indicates that the majority of users had lower values for these variables. For variables with uniform distributions, it suggests that it was equally probable for users to exhibit values at any point within the variable's range.
#
# 2. Was there anything that led you to believe the data was erroneous or problematic in any way?
#
# A few variables exhibited outliers that seemed highly unlikely or potentially impossible, for instance, driven_km_drives. Additionally, there may be issues with some of the monthly variables like activity_days and driving_days, as one shows a maximum value of 31 and the other 30. This discrepancy suggests that the data for these two variables might not have been collected within the same month.
#
# 3. Did your investigation give rise to further questions that you would like to explore or ask the Waze team about?
#
# It would be important to request confirmation from the Waze data team regarding whether the monthly variables were gathered in the same month, considering the discrepancy where some max out at 30 days and others at 31 days. It is also interesting to observe a sudden increase in app usage among long-standing users over the past month. Waze could provide information on whether there is other data that supports this observation and whether there are any specific circumpsatnces that have brough upon this change in behaviour. It will also be important to check the validity of the data associated with driven_min_drives and driven_km_drives, as these values seem highly improbable.
#
# 4. What percentage of users churned and what percentage were retained?
#
# ~18% of users churned and \~82% were retained.
#
# 5. What factors correlated with user churn? How?
#
# The distance traveled per driving day showed a positive link with user churn, indicating that users who drove longer distances each driving day were more prone to churn. Conversely, the frequency of driving days exhibited a negative relationship with churn. Users who drove on more days in the previous month were less inclined to churn.
#
# 6. Did newer uses have greater representation in this dataset than users with longer tenure? How do you know?
#
# No, the data includes users of varying durations, from brand new to approximately 10 years, in a relatively equal manner. This is confirmed by the histogram for n_days_after_onboarding, which shows an even distribution for this variable.
